# %%
import pandas as pd
import matplotlib.pyplot as plt
import category_encoders as ce
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("adult.csv")
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
le = LabelEncoder()
df['workclass'] = le.fit_transform(df['workclass'].values)
df['salary'] = le.fit_transform(df['salary'].values)
df['salary'] = le.fit_transform(df['salary'].values)
df['marital-status'] = le.fit_transform(df['marital-status'].values)
df['education'] = le.fit_transform(df['education'].values)

# %%
df.tail()
# Out:
#        age  workclass  fnlwgt   education  education-num      marital-status  \
# 32556   27          4  257302  Assoc-acdm             12  Married-civ-spouse
# 32557   40          4  154374     HS-grad              9  Married-civ-spouse
# 32558   58          4  151910     HS-grad              9             Widowed
# 32559   22          4  201490     HS-grad              9       Never-married
# 32560   52          5  287927     HS-grad              9  Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 32556       Tech-support         Wife  White  Female             0
# 32557  Machine-op-inspct      Husband  White    Male             0
# 32558       Adm-clerical    Unmarried  White  Female             0
# 32559       Adm-clerical    Own-child  White    Male             0
# 32560    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country  salary
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  int32
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int32(1), int64(6), object(8)
# memory usage: 3.6+ MB

# %%
df.describe()
# Out:
#                 age     workclass        fnlwgt  education-num  capital-gain  \
# count  32561.000000  32561.000000  3.256100e+04   32561.000000  32561.000000
# mean      38.581647      3.868892  1.897784e+05      10.080679   1077.648844
# std       13.640433      1.455960  1.055500e+05       2.572720   7385.292085
# min       17.000000      0.000000  1.228500e+04       1.000000      0.000000
# 25%       28.000000      4.000000  1.178270e+05       9.000000      0.000000
# 50%       37.000000      4.000000  1.783560e+05      10.000000      0.000000
# 75%       48.000000      4.000000  2.370510e+05      12.000000      0.000000
# max       90.000000      8.000000  1.484705e+06      16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  32561.000000    32561.000000
# mean      87.303830       40.437456
# std      402.960219       12.347429
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# ...

# %%
df.value_counts()
# Out:
# age  workclass  fnlwgt  education     education-num  marital-status      occupation         relationship   race   sex     capital-gain  capital-loss  hours-per-week  native-country  salary
# 25   4          195994  1st-4th       2              Never-married       Priv-house-serv    Not-in-family  White  Female  0             0             40              Guatemala       <=50K     3
# 23   4          240137  5th-6th       3              Never-married       Handlers-cleaners  Not-in-family  White  Male    0             0             55              Mexico          <=50K     2
# 38   4          207202  HS-grad       9              Married-civ-spouse  Machine-op-inspct  Husband        White  Male    0             0             48              United-States   >50K      2
# 30   4          144593  HS-grad       9              Never-married       Other-service      Not-in-family  Black  Male    0             0             40              ?               <=50K     2
# ...

# %%
df.median(numeric_only=True)
# Out:
# age                   37.0
# workclass              4.0
# fnlwgt            178356.0
# education-num         10.0
# capital-gain           0.0
# capital-loss           0.0
# hours-per-week        40.0
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#     age  workclass  fnlwgt  education-num  capital-gain  capital-loss  \
# 0  36.0        4.0  123011            9.0           0.0           0.0
# 1   NaN        NaN  164190            NaN           NaN           NaN
# 2   NaN        NaN  203488            NaN           NaN           NaN
#
#    hours-per-week
# 0            40.0
# 1             NaN
# 2             NaN

# %%
df.skew(numeric_only=True)
# Out:
# age                0.558743
# workclass         -0.752024
# fnlwgt             1.446980
# education-num     -0.311676
# capital-gain      11.953848
# capital-loss       4.594629
# hours-per-week     0.227643
# dtype: float64

# %%
df.kurt(numeric_only=True)
# Out:
# age                -0.166127
# workclass           1.682387
# fnlwgt              6.218811
# education-num       0.623444
# capital-gain      154.799438
# capital-loss       20.376802
# hours-per-week      2.916687
# dtype: float64

# %%
plt.scatter(df['age'],df['fnlwgt'])

# %%
plt.figure(figsize=(7,7))
plt.pie(df['workclass'].value_counts(),radius=0.8)
plt.legend(df['workclass'].value_counts().keys())
